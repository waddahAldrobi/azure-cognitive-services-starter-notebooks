      "timestamp": "1974-12-01T00:00:00Z",
      "value": 813
    },
    {
      "timestamp": "1975-01-01T00:00:00Z",
      "value": 834
    },
    {
      "timestamp": "1975-02-01T00:00:00Z",
      "value": 782
    },
    {
      "timestamp": "1975-03-01T00:00:00Z",
      "value": 892
    },
    {
      "timestamp": "1975-04-01T00:00:00Z",
      "value": 903
    },
    {
      "timestamp": "1975-05-01T00:00:00Z",
      "value": 966
    },
    {
      "timestamp": "1975-06-01T00:00:00Z",
      "value": 937
    },
    {
      "timestamp": "1975-07-01T00:00:00Z",
      "value": 896
    },
    {
      "timestamp": "1975-08-01T00:00:00Z",
      "value": 858
    },
    {
      "timestamp": "1975-09-01T00:00:00Z",
      "value": 817
    },
    {
      "timestamp": "1975-10-01T00:00:00Z",
      "value": 827
    },
    {
      "timestamp": "1975-11-01T00:00:00Z",
      "value": 797
    },
    {
      "timestamp": "1975-12-01T00:00:00Z",
      "value": 843
    }
  ],
  "granularity": "monthly",
  "maxAnomalyRatio": 0.25,
  "sensitivity": 95
}

# %%
plt.style.use('seaborn') 

format = "%Y-%m-%dT%H:%M:%SZ" 

dates = [datetime.datetime.strptime(d['timestamp'], format)  for d in request['series']]
values = [d["value"]  for d in request['series']]

# %%
plt.plot_date(dates, values)
plt.ylim(top=1100, bottom=0) #ymax is your value

plt.show()

# %% [markdown]
# ## Uses the data points in the request build a model and detect if the last point is an anomaly

# %%
external_ip = #External IP
port = #PORT
api = '/anomalydetector/v1.0/timeseries/last/detect'
endpoint = 'http://'+ external_ip +':'+ port + api

# %%
# if request is in a JSON file

# f = open('data.json',)
# request = json.load(f)
# f.close()

# %%
response = requests.post(endpoint, \
                         headers={'accept': 'application/json'
                         , 'Content-Type': 'application/json'},
                         json=request)

# %%
print(json.dumps(json.loads(response.content), indent=4, sort_keys=True))
# Out:
# {
#     "expectedValue": 809.5658016931228,
#     "isAnomaly": false,
#     "isNegativeAnomaly": false,
#     "isPositiveAnomaly": false,
#     "lowerMargin": 40.47829008465612,
#     "period": 12,
#     "suggestedWindow": 49,
#     "upperMargin": 40.47829008465612
# }

# %% [markdown]
# ## Uses the data points in the request to build a model and infer on every point in the request

# %%
api = '/anomalydetector/v1.0/timeseries/entire/detect'
endpoint = 'http://'+ external_ip +':'+ port + api

# %%
response = requests.post(endpoint, \
                         headers={'accept': 'application/json'
                         , 'Content-Type': 'application/json'},
                         json=request)

# %% [markdown]
# ### Entire output

# %%
print(json.dumps(json.loads(response.content), indent=4, sort_keys=True))
# Out:
# {
#     "expectedValues": [
#         827.7940908243968,
#         798.9133774671927,
#         888.6058431807189,
#         900.5606407986661,
#         962.8389426378304,
#         933.2591606306954,
#         891.0784104799666,
#         856.1781601363697,
#         809.8987227908941,
#         807.375129007505,
#         46.860568139658994,
#         44.79773394550648,
#         43.100436842068234,
#         40.82331171048713,
#         40.72148872762352,
#         38.59307239579675,
#         40.59296356733648,
#         41.5949913960776,
#         40.1473772398582,
#         44.62842203717537,
#         45.22744107266908,
#         48.34263531922352,
#         46.865841955015185,
#         44.75900018362722,
#         43.018247981783134,
#         40.70853642984525,
#         40.604152501724,
#         38.47317522463959,
#         40.487168272949134
#     ]
# }

# %% [markdown]
# ### Output of a specifc point (using consistent index)

# %%
result = json.loads(response.content)

# %%
result.keys()
# Out:
# dict_keys(['period', 'expectedValues', 'upperMargins', 'lowerMargins', 'isAnomaly', 'isNegativeAnomaly', 'isPositiveAnomaly'])

# %%
# of the 5th point
idx = 4

for key in result.keys():
    if key == 'period':
        print(key, result[key])
    else:
        print(key, result[key][idx])
# Out:
# period 12
# expectedValues 962.8389426378304
# upperMargins 48.14194713189147
# lowerMargins 48.14194713189147
# isAnomaly False
# isNegativeAnomaly False
# isPositiveAnomaly False

# %% [markdown]
# ## Detect poins in which a trend change occured

# %%
api = '/anomalydetector/v1.0/timeseries/changepoint/detect'
endpoint = 'http://'+ external_ip +':'+ port + api

# %%
response = requests.post(endpoint, \
                         headers={'accept': 'application/json'
                         , 'Content-Type': 'application/json'},
                         json=request)

# %% [markdown]
# ### Entire output

# %%
print(json.dumps(json.loads(response.content), indent=4, sort_keys=True))
# Out:
# {
#     "confidenceScores": [
#         0.0,
#         9.834819e-15,
#         0.0,
#         0.000617664,
#         0.000823552,
#         0.00195540162,
#         0.002491914,
#         0.004261762,
#         0.00526829436,
#         0.01399884,
#         0.01973938,
#         0.03757099,
#         0.0500909351,
#         0.0694752,
#         0.08359597,
#         0.07265493,
#         0.06359886,
#         0.01362037,
#         0.0266971514,
#         0.082947135,
#         0.156659678,
#         9.834819e-15,
#         1.96696382e-14,
#         0.008487225,
#         0.0113162994,
#         0.0266489387,
#         0.0339111052,
#         0.0156878941,
#         0.004000387,
#         0.01275147,
#         0.0239799861,
#         0.0514795221,
#         0.07085853,
#         0.147944942,
#         2.95044581e-14,
#         0.0048048906,
#         0.005765869,
#         0.005804451,
#         0.00554642128,
#         0.00181066641,
#         0.0004188203,
#         0.00138140423,
#         0.00198634272,
#         0.0030204386,
#         0.0037108853,
#         0.00598427141,
#         0.00761607941,
#         0.0102421185
#     ],
#     "isChangePoint": [
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         true,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         true,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false,
#         false
#     ],
#     "period": 12
# }

# %%
result = json.loads(response.content)

# %%
result.keys()
# Out:
# dict_keys(['period', 'isChangePoint', 'confidenceScores'])

# %%
# of the 5th point
idx = 4

for key in result.keys():
    if key == 'period':
        print(key, result[key])
    else:
        print(key, result[key][idx])
# Out:
# period 12
# isChangePoint False
# confidenceScores 0.000823552
